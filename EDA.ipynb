# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Групповой проект №2. DE: Scraping & API

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 24.03.2026
#
# __Дедлайн по записи в таблицу:__ 4:00 29.03.2026
#
# __Дедлайн по загрузке работ:__ 4:00 11.04.2026
#
# __Защита проекта:__ 13.04.2026 - 15.04.2026

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняемому ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой в обязательном порядке проверяется и учитывается в оценке вклад **каждого участника** в общую работу команды. Вследствие этого крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости команда большинством голосов имеет право исключить человека из команды **до загрузки работ** в систему [Anytask](https://anytask.org/), сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1t5GwRcerMBZVpmEDsT0Sm_fO4hlE4NJXnF0y2Uqa_iw/edit?usp=sharing

# %% [markdown]
# ## Отправка материалов группового проекта

# %% [markdown]
# Во избежание использования при выполнении группового проекта генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации (то есть, например, для автоматической генерации кода по одному из этапов) **одному из участников команды** необходимо предварительно загрузить работу в систему [Anytask](https://anytask.org/). Наличие сгенерированного кода или любого другого случая "несанкционированного" использования нейросетей будет считаться плагиатом, и такой проект будет оценен в 0 баллов для всех участников. При отсутствии своевременно загруженных файлов с проектом команде также выставляется 0 за проект.
#
# *Примечание: презентацию проекта загружать необязательно, важно отправить содержательные файлы с кодом и ссылку на репозиторий GitHub*

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(29032026)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий, дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современном мире данных эффективный сбор и интеграция информации из различных источников являются фундаментом для принятия обоснованных решений и успешного ведения бизнеса. Компании, стремясь к конкурентоспособности, активно используют технологии веб-скрапинга и взаимодействия с API для автоматизации процесса сбора данных, обеспечения их актуальности и полноты.
#
# В данном проекте вы на реальных данных попрактикуетесь в том, как осуществляется веб-скрапинг различных сайтов для извлечения необходимой информации, а также в работе с API популярных сервисов для получения структурированных данных. Вы научитесь применять современные инструменты и библиотеки, отражающие различные этапы DE, обрабатывать и очищать полученную информацию, а также интегрировать данные из различных источников для последующего использования их в аналитических и бизнес-задачах.

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# В рамках этого проекта вы сами найдете датасет, с которым будете работать. Точнее, не найдете, а... соберёте его самостоятельно на основе источников!
#
# Итак, начните с того, что выберите два сайта/портала со схожей тематикой (например, NYT и Bloomberg). Их тематика должна позволять в дальнейшем объединить данные в единую таблицу. Один из этих двух сайтов нужно будет обработать с помощью средств Web-Scraping'a и Data Parsing'a; другой же — используя API.
#
# Определившись с источниками, непосредственно проделайте скачивание данных путём скрейпинга и методами API соответственно и затем объедините всё в финальный датасет. Обязательным требованием к датасету является также наличие в нём как минимум одного столбца с текстовыми данными: описание, состав, комментарии о чём-либо, текст заметки/новости, или что-то ещё.
#
# Кроме того, разумеется, следует помнить, что полученный датасет должен, конечно, быть осмысленным с бизнес-точки зрения и потенциально позволять решать какую-то конкретную бизнес-задачу. Это как минимум означает, что каждому объекту, имеющему своё признаковое пространство — в том числе с текстовым признаком, — должно также соответствовать значение некоторой целевой переменной, которая является релевантной в рамках выбранной вами предметной области.

# %% [markdown]
# Примеры задач, которые мы можем предложить вам в качестве источника для вдохновения — пожалуйста, ни в коем случае не воспринимайте это как исчерпывающий список — это действительно всего лишь примеры:
#
# * Сайт новостей: текстовый столбец — сама новость; признаки — различные характеристики новости: автор, дата публикации, тип новости и т.д.; целевая переменная — количество просмотров новости (можно поделить на число дней с момента даты публикации, чтобы получить «среднее число просмотров в день», что ещё нагляднее)
#
# * Сайт с товарами/книгами/фильмами: текстовый столбец — описание товара/книги/фильма; признаки — различные характеристики объекта: цена, год производства/выпуска, компания-производитель и т.д.; целевая переменная — средний рейтинг объекта
#
# * Блоги: текстовый столбец — тексты заметок; признаки — различные характеристики заметки: автор, время публикации, количество прикрепленных изображений и т.д.; целевая переменная — число просмотров
#
# * И любые другие ваши идеи, которые подходят под описанный выше формат

# %% [markdown]
# После сбора данных и объединения их в общий датасет, необходимо очистить его от мусора (в том числе, желательно с использованием регулярных выражений); посчитать различные статистики по собранным данным (в случае если столбец текстовый, то, например, посчитать частотности слов, выявляя наиболее частотные слова, и т.д.); а также в целом провести EDA в контексте той бизнес-задачи, которую мы потенциально хотим решить по полученному датасету. В конце сделать выводы из проделанной работы.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже для вашего удобства еще раз в краткой форме представляем примерные этапы реализации проекта:
#
# - Выбор источников данных, в соответствии с требованиями, описанными выше
# - Формулировка бизнес-задачи, которую могла бы хотеть решить компания/платформа, на основе собираемых данных
# - Обоснование сформулированной бизнес-задачи
# - Извлечение данных путём работы с API
# - Извлечение данных путём скрейпинга и парсинга
# - Первичная обработка данных (EDA)
# - Получение и агрегация результатов, финальные выводы

# %% [markdown]
# ### Общие требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию, а также репозиторий с кодом на GitHub. Демонстрация репозитория и защита презентации перед комиссией осуществляется в фиксированную дату.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных с платформы — и дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных и извлечь полезные инсайты из проделанной работы. А в конце, конечно, — презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект, исходя из того, что ваша цель — представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ### Технические требования

# %% [markdown]
# Ниже чуть более детализированно будут представлены минимальные технические требования по всем основным этапам и составным частям выполняемого вами группового проекта.

# %% [markdown]
# #### Обязательный сбор данных через API

# %% [markdown]
# * Необходимо реализовать сбор данных через API для как минимум одного веб-сайта
# * Как минимум часть функций API должны применяться с обязательной передачей API-ключа (не общедоступные API)
# * При формировании датасета должно осуществляться **не менее 5** различных запросов к API
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Обязательный сбор данных посредством скрейпинга

# %% [markdown]
# * Необходимо реализовать сбор и парсинг данных через библиотеки `requests` / `bs4` и другие рассмотренные в рамках семинара для как минимум одного веб-сайта, отличного от веб-сайта из предыдущего пункта
# * Получившийся датасет должен содержать **не менее 10 000** записей
# * Для очистки и подготовки датасета рекомендуется использование регулярных выражений
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Разведочный анализ данных (EDA)

# %% [markdown]
# * Изучить особенности данных в рамках объединённого датасета:
#   * Есть ли пропущенные значения? Сколько? Какова их доля от общего числа объектов для каждого конкретного признака? И, в целом, насколько ваш датасет “разрежен” в контексте пропущенных значений? Выдвинуть и (желательно) проверить гипотезу, что могут означать пропущенные значения? Осмысленно и аргументированно обработать пропуски.
#   * Есть ли ошибочные  (например, отрицательный возраст или пятиметровый рост человека; 3-й класс в задаче бинарной классификации) значения (признаки, целевая переменная) в данных? Обработать их.
#   * Есть ли выбросы в данных? По возможности обработать их.
# * Изучить поведение каждого признака в отдельности, его связь с целевой переменной, а также попарные корреляции (в том числе и в особенности с таргетом). Визуализировать попарные распределения признаков и корреляции наиболее значимых.
# * Построить подходящие сводные таблицы и прочие диаграммы.
# * Если проведенный вами анализ позволяет сделать какие-либо выводы, постараться сформулировать их максимально глубоко и развернуто. Упомянуть, как можно задействовать в дальнейшем приобретенные вами на этом этапе знания в решаемой задаче.
# * Осуществить и другие осмысленные действия в рамках процесса EDA.

# %% [markdown]
# #### GitHub и требования при использовании СКВ

# %% [markdown]
# *   Для выполнения задания вы должны создать проект на GitHub (один репозиторий на всю команду!)
# *   Необходимо добавить в репозиторий `.gitignore` и не грузить в репозиторий лишние файлы
# *   Необходимо добавить в репозиторий `README.md` с подробным описанием проекта. В этот файл также необходимо добавить подробное описание данных — описание признаков, их тип, количество объектов каждого класса (в задачах классификации), информацию о пропущенных значениях (в т.ч о типичных филлерах, если это не `nan`). Также добавляйте другие релевантные вашей задачи описательные характеристики данных. После чтения этого файла у человека со стороны не должно остаться никаких вопросов про данные
# *   В репозитории проекта размещаются ноутбуки / скрипты со сбором данных
# *   Коммиты делаются осмысленно, с понятными внешнему наблюдателю комментариями — что было сделано по факту
# *   При разработке необходимо соблюдать [гитфлоу](https://www.umgum.com/gitlab-workflow)

# %% [markdown]
# #### Артефакты по окончании работы над проектом

# %% [markdown]
# * Ноутбуки / скрипты со сбором и извлечением данных
# * Ноутбуки c осуществлением EDA
# * Файл `.gitignore`
# * Заполненный файл `README.md` в репозитории проекта на гитхабе со ссылкой на данные и их подробным описанием, с выводами о проведенном EDA

# %% [markdown]
# #### Логирование

# %% [markdown]
# * Для получения высоких баллов добавьте в ваш проект логирование. Потренируйтесь включать и выключать его через файл настроек, а также задавать уровень логирования через этот же файл (не в приложении)
# * Запустите ваш код, чтобы сохранился файл с логами
# * Про логи можно почитать [тут](https://habr.com/ru/companies/wunderfund/articles/683880/) и [тут](https://tproger.ru/articles/shpargalka-po-logirovaniju-na-python)

# %% [markdown]
# #### Библиотека Selenium

# %% [markdown]
# * Для получения высоких баллов используйте библиотеку Selenium при сборе данных
# * Реализуйте имитацию работы пользователя через Selenium
# * Про данную библиотеку можно почитать [тут](https://habr.com/ru/companies/selectel/articles/754674/) и [тут](https://happypython.ru/2022/11/27/selenium-chromedriver-find-elements/)

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10 балльной шкале, исходя из 3 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задачи и EDA (до 3,5 баллов)
#
# Данный критерий оценивает, насколько обоснованной и осмысленной получилась решаемая бизнес-задача; насколько полно был осуществлен переход от бизнес-задачи к пайплайну подготовки данных (насколько в реальности формируемый датасет соответствует исходной постановке задачи с точки зрения интересов компании и насколько может помочь в решении такой задачи); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.

# %% [markdown]
# ### Критерий 2. GitHub (до 1 балла)
#
# Данный критерий оценивает, насколько корректным и квалифицированным было применение средств системы контроля версий в проекте; насколько были выполнены представленные в задании требования по всем необходимым файлам и условиям в рамках работы с GitHub; а также насколько эффективно данная система в действительности использовалась командой для распараллеливания задач по проекту.

# %% [markdown]
# ### Критерий 3. Инструменты извлечения данных (до 5,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных автоматизированным образом с сайтов и порталов. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.
#
# *__Важно:__ в случае оценки __1 балл и ниже__ за этот критерий — оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить __больше 1 балла__ только при условии применения как средств Data Scraping (автоматического считывания HTML-кода страниц с последующей его обработкой), так и средств API (получению данных с использованием официальных протоколов компании/портала). При этом средства Scraping и API следует применять к разным компаниям/порталам, но представленным в рамках одной и той же предметной области (бизнес-задачи).*
#
# *По данному критерию можно получить **3 балла и выше** только при условии использования в проекте логирования __ИЛИ__ библиотеки Selenium.*
#
# *По данному критерию можно получить **4 балла и выше** только при условии использования в проекте логирования __И__ библиотеки Selenium.*
#
# *По данному критерию можно получить **5 баллов и выше** только при условии использования в проекте логирования, библиотеки Selenium и, кроме этого, обоснованного применения дополнительных инструментов/подходов/библиотек, не упомянутых ранее в этом ноутбуке и не рассматривавшихся в рамках соответствующего семинара.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 =  pd.read_csv('final_dataset_api.csv')
data2 =  pd.read_csv('final_scraping_dataset_10000.csv')
data = pd.merge(data1, data2, on='name', how='left')
data
# Out:
#       Unnamed: 0     id                              name    released  \
# 0              0   3498                Grand Theft Auto V  2013-09-17
# 1              1   3328          The Witcher 3: Wild Hunt  2015-05-18
# 2              2   4200                          Portal 2  2011-04-18
# 3              3   4291  Counter-Strike: Global Offensive  2012-08-21
# 4              4   5286                Tomb Raider (2013)  2013-03-05
# ...          ...    ...                               ...         ...
# 9995        9995  19244       Silverfall: Earth Awakening  2008-07-18
# 9996        9996  38567                          Mabinogi  2008-03-27
# 9997        9997  21418                      Age of Booty  2008-10-15
# 9998        9998   5309                            Sudoku  2008-07-11
# 9999        9999  13536                            Portal  2007-10-09
#
#      dataset_label  source_window                             slug  rating  \
# 0         released           2013               grand-theft-auto-v    4.47
# 1         released           2015          the-witcher-3-wild-hunt    4.64
# 2         released           2011                         portal-2    4.58
# 3         released           2012  counter-strike-global-offensive    3.57
# 4         released           2013                      tomb-raider    4.06
# ...            ...            ...                              ...     ...
# 9995      released           2008       silverfall-earth-awakening    3.00
# 9996      released           2008                         mabinogi    3.40
# 9997      released           2008                     age-of-booty    3.80
# 9998      released           2008                           sudoku    2.48
# 9999      released           2007                           portal    4.49
#
#       ratings_count  reviews_count  ...  \
# 0              7363           7499  ...
# 1              7178           7297  ...
# 2              6086           6143  ...
# 3              3634           3671  ...
# 4              4091           4125  ...
# ...             ...            ...  ...
# 9995             16             16  ...
# 9996             15             15  ...
# 9997             15             15  ...
# 9998             23             23  ...
# 9999           5007           5052  ...
#
#                                                  stores  \
# 0     Steam, PlayStation Store, Epic Games, Xbox 360...
# 1     GOG, PlayStation Store, Steam, Xbox Store, Nin...
# 2     Xbox Store, Steam, PlayStation Store, Xbox 360...
# 3              PlayStation Store, Steam, Xbox 360 Store
# 4     Xbox 360 Store, Steam, PlayStation Store, Goog...
# ...                                                 ...
# 9995                                              Steam
# 9996                                              Steam
# 9997                  Xbox 360 Store, Steam, Xbox Store
# 9998  PlayStation Store, Nintendo Store, Steam, App ...
# 9999                                 Steam, Google Play
#
#                                              developers  \
# 0                        Rockstar North, Rockstar Games
# 1                                        CD PROJEKT RED
# 2                                        Valve Software
# 3             Valve Software, Hidden Path Entertainment
# 4                                      Crystal Dynamics
# ...                                                 ...
# 9995                                       Monte Cristo
# 9996                                NEXON KOREA, devCAT
# 9997                                  Certain Affinity™
# 9998  Electronic Arts, 1C Wireless, Taranau Aliaksei...
# 9999          Valve Software, NVIDIA Lightspeed Studios
#
#                                              publishers steam_review_percent  \
# 0                                        Rockstar Games                 79.0
# 1                                        CD PROJEKT RED                 96.0
# 2                                Electronic Arts, Valve                 98.0
# 3                                                 Valve                 86.0
# 4                                           Square Enix                  NaN
# ...                                                 ...                  ...
# 9995                             Focus Home Interactive                 72.0
# 9996                               Nexon, Nexon America                100.0
# 9997                                             Capcom                  NaN
# 9998  Electronic Arts, SlyGames, Taranau Aliaksei, R...                 80.0
# 9999      Valve, Buka Entertainment, NVIDIA, CyberFront                 98.0
#
#      steam_review_count       steam_review_label steam_price_text  \
# 0               56707.0          Mostly Positive           $14.99
# 1              234151.0  Overwhelmingly Positive           $29.99
# 2              169118.0  Overwhelmingly Positive            $5.79
# 3             2513715.0            Very Positive             Free
# 4                   NaN                      NaN              NaN
# ...                 ...                      ...              ...
# 9995               95.0          Mostly Positive           41 руб
# 9996               11.0                 Positive          200 руб
# 9997                NaN                      NaN              NaN
# 9998               15.0                 Positive          170 руб
# 9999            81012.0  Overwhelmingly Positive          385 руб
#
#      steam_discount_pct steam_platform_flags  steam_app_id
# 0                  50.0                  win       3240220
# 1                   NaN                  win        292030
# 2                   NaN           linux, win           620
# 3                   NaN           linux, win           730
# 4                   NaN                  NaN           NaN
# ...                 ...                  ...           ...
# 9995               85.0                  win          4470
# 9996                NaN                music        509081
# 9997                NaN                  NaN           NaN
# 9998               15.0             mac, win       4215050
# 9999                NaN           linux, win           400
#
# [10000 rows x 26 columns]

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
def unify_price(s):
    if pd.isna(s):
        return s
    elif s[0] == '$':
        return float(s[1:])
    elif s[-3:] == 'руб':
        s = s.replace(',', '.')
        return np.round(float(s[:-3]) / 76, 2)
    elif s == 'Free':
        return 0
    else:
        return s

# %%
data['steam_price_text'] = data['steam_price_text'].apply(unify_price)
data['steam_price_text'] = np.where(data['steam_discount_pct'] > 0, np.round(data['steam_price_text'] / (1 - data['steam_discount_pct'] / 100), 2), data['steam_price_text'])
data
# Out:
#       Unnamed: 0     id                              name    released  \
# 0              0   3498                Grand Theft Auto V  2013-09-17
# 1              1   3328          The Witcher 3: Wild Hunt  2015-05-18
# 2              2   4200                          Portal 2  2011-04-18
# 3              3   4291  Counter-Strike: Global Offensive  2012-08-21
# 4              4   5286                Tomb Raider (2013)  2013-03-05
# ...          ...    ...                               ...         ...
# 9995        9995  19244       Silverfall: Earth Awakening  2008-07-18
# 9996        9996  38567                          Mabinogi  2008-03-27
# 9997        9997  21418                      Age of Booty  2008-10-15
# 9998        9998   5309                            Sudoku  2008-07-11
# 9999        9999  13536                            Portal  2007-10-09
#
#      dataset_label  source_window                             slug  rating  \
# 0         released           2013               grand-theft-auto-v    4.47
# 1         released           2015          the-witcher-3-wild-hunt    4.64
# 2         released           2011                         portal-2    4.58
# 3         released           2012  counter-strike-global-offensive    3.57
# 4         released           2013                      tomb-raider    4.06
# ...            ...            ...                              ...     ...
# 9995      released           2008       silverfall-earth-awakening    3.00
# 9996      released           2008                         mabinogi    3.40
# 9997      released           2008                     age-of-booty    3.80
# 9998      released           2008                           sudoku    2.48
# 9999      released           2007                           portal    4.49
#
#       ratings_count  reviews_count  ...  \
# 0              7363           7499  ...
# 1              7178           7297  ...
# 2              6086           6143  ...
# 3              3634           3671  ...
# 4              4091           4125  ...
# ...             ...            ...  ...
# 9995             16             16  ...
# 9996             15             15  ...
# 9997             15             15  ...
# 9998             23             23  ...
# 9999           5007           5052  ...
#
#                                                  stores  \
# 0     Steam, PlayStation Store, Epic Games, Xbox 360...
# 1     GOG, PlayStation Store, Steam, Xbox Store, Nin...
# 2     Xbox Store, Steam, PlayStation Store, Xbox 360...
# 3              PlayStation Store, Steam, Xbox 360 Store
# 4     Xbox 360 Store, Steam, PlayStation Store, Goog...
# ...                                                 ...
# 9995                                              Steam
# 9996                                              Steam
# 9997                  Xbox 360 Store, Steam, Xbox Store
# 9998  PlayStation Store, Nintendo Store, Steam, App ...
# 9999                                 Steam, Google Play
#
#                                              developers  \
# 0                        Rockstar North, Rockstar Games
# 1                                        CD PROJEKT RED
# 2                                        Valve Software
# 3             Valve Software, Hidden Path Entertainment
# 4                                      Crystal Dynamics
# ...                                                 ...
# 9995                                       Monte Cristo
# 9996                                NEXON KOREA, devCAT
# 9997                                  Certain Affinity™
# 9998  Electronic Arts, 1C Wireless, Taranau Aliaksei...
# 9999          Valve Software, NVIDIA Lightspeed Studios
#
#                                              publishers steam_review_percent  \
# 0                                        Rockstar Games                 79.0
# 1                                        CD PROJEKT RED                 96.0
# 2                                Electronic Arts, Valve                 98.0
# 3                                                 Valve                 86.0
# 4                                           Square Enix                  NaN
# ...                                                 ...                  ...
# 9995                             Focus Home Interactive                 72.0
# 9996                               Nexon, Nexon America                100.0
# 9997                                             Capcom                  NaN
# 9998  Electronic Arts, SlyGames, Taranau Aliaksei, R...                 80.0
# 9999      Valve, Buka Entertainment, NVIDIA, CyberFront                 98.0
#
#      steam_review_count       steam_review_label steam_price_text  \
# 0               56707.0          Mostly Positive            29.98
# 1              234151.0  Overwhelmingly Positive            29.99
# 2              169118.0  Overwhelmingly Positive             5.79
# 3             2513715.0            Very Positive             0.00
# 4                   NaN                      NaN              NaN
# ...                 ...                      ...              ...
# 9995               95.0          Mostly Positive             3.60
# 9996               11.0                 Positive             2.63
# 9997                NaN                      NaN              NaN
# 9998               15.0                 Positive             2.64
# 9999            81012.0  Overwhelmingly Positive             5.07
#
#      steam_discount_pct steam_platform_flags  steam_app_id
# 0                  50.0                  win       3240220
# 1                   NaN                  win        292030
# 2                   NaN           linux, win           620
# 3                   NaN           linux, win           730
# 4                   NaN                  NaN           NaN
# ...                 ...                  ...           ...
# 9995               85.0                  win          4470
# 9996                NaN                music        509081
# 9997                NaN                  NaN           NaN
# 9998               15.0             mac, win       4215050
# 9999                NaN           linux, win           400
#
# [10000 rows x 26 columns]

# %%
data.isna().sum()
# Out:
# Unnamed: 0                 0
# id                         0
# name                       0
# released                   0
# dataset_label              0
# source_window              0
# slug                       0
# rating                     0
# ratings_count              0
# reviews_count              0
# playtime                   0
# added                      0
# suggestions_count          0
# genres                     0
# tags                     176
# platforms                  0
# stores                     0
# developers                36
# publishers                86
# steam_review_percent    2076
# steam_review_count      2076
# steam_review_label      2076
# steam_price_text        1973
# steam_discount_pct      9183
# steam_platform_flags    1819
# steam_app_id            1819
# dtype: int64

# %%
data = data.drop(columns=['steam_discount_pct', 'id', 'steam_app_id'])

# %% [markdown]
# удаляем steam_discount_pct потому что столбец 91% пустой и не несет прикоадного смысла для анализа

# %%
df = data.dropna(subset=['steam_review_percent','steam_review_count','steam_review_label','steam_price_text','steam_platform_flags','tags', 'developers',
'publishers'])

# %%
def split_value(value):
    return [v.strip() for v in str(value).split(',')]

# %%
df['developers_list'] = df['developers'].apply(split_value)
df['publishers_list'] = df['publishers'].apply(split_value)
df
# Out:
# /tmp/ipykernel_10659/3944294805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['developers_list'] = df['developers'].apply(split_value)
# /tmp/ipykernel_10659/3944294805.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publishers_list'] = df['publishers'].apply(split_value)
#       Unnamed: 0                              name    released dataset_label  \
# 0              0                Grand Theft Auto V  2013-09-17      released
# 1              1          The Witcher 3: Wild Hunt  2015-05-18      released
# 2              2                          Portal 2  2011-04-18      released
# 3              3  Counter-Strike: Global Offensive  2012-08-21      released
# 5              5                     Left 4 Dead 2  2009-11-17      released
# ...          ...                               ...         ...           ...
# 9994        9994                       Empires Mod  2008-07-28      released
# 9995        9995       Silverfall: Earth Awakening  2008-07-18      released
# 9996        9996                          Mabinogi  2008-03-27      released
# 9998        9998                            Sudoku  2008-07-11      released
# 9999        9999                            Portal  2007-10-09      released
#
#       source_window                             slug  rating  ratings_count  \
# 0              2013               grand-theft-auto-v    4.47           7363
# 1              2015          the-witcher-3-wild-hunt    4.64           7178
# 2              2011                         portal-2    4.58           6086
# 3              2012  counter-strike-global-offensive    3.57           3634
# 5              2009                    left-4-dead-2    4.10           3407
# ...             ...                              ...     ...            ...
# 9994           2008                      empires-mod    1.64             11
# 9995           2008       silverfall-earth-awakening    3.00             16
# 9996           2008                         mabinogi    3.40             15
# 9998           2008                           sudoku    2.48             23
# 9999           2007                           portal    4.49           5007
#
#       reviews_count  playtime  ...  \
# 0              7499        74  ...
# 1              7297        43  ...
# 2              6143        11  ...
# 3              3671        64  ...
# 5              3434         9  ...
# ...             ...       ...  ...
# 9994             11         1  ...
# 9995             16         1  ...
# 9996             15         2  ...
# 9998             23         1  ...
# 9999           5052         4  ...
#
#                                                  stores  \
# 0     Steam, PlayStation Store, Epic Games, Xbox 360...
# 1     GOG, PlayStation Store, Steam, Xbox Store, Nin...
# 2     Xbox Store, Steam, PlayStation Store, Xbox 360...
# 3              PlayStation Store, Steam, Xbox 360 Store
# 5                                 Steam, Xbox 360 Store
# ...                                                 ...
# 9994                                              Steam
# 9995                                              Steam
# 9996                                              Steam
# 9998  PlayStation Store, Nintendo Store, Steam, App ...
# 9999                                 Steam, Google Play
#
#                                              developers  \
# 0                        Rockstar North, Rockstar Games
# 1                                        CD PROJEKT RED
# 2                                        Valve Software
# 3             Valve Software, Hidden Path Entertainment
# 5                   Valve Software, Turtle Rock Studios
# ...                                                 ...
# 9994                                            Empires
# 9995                                       Monte Cristo
# 9996                                NEXON KOREA, devCAT
# 9998  Electronic Arts, 1C Wireless, Taranau Aliaksei...
# 9999          Valve Software, NVIDIA Lightspeed Studios
#
#                                              publishers steam_review_percent  \
# 0                                        Rockstar Games                 79.0
# 1                                        CD PROJEKT RED                 96.0
# 2                                Electronic Arts, Valve                 98.0
# 3                                                 Valve                 86.0
# 5                        Electronic Arts, Valve, Akella                 97.0
# ...                                                 ...                  ...
# 9994                                            Empires                 86.0
# 9995                             Focus Home Interactive                 72.0
# 9996                               Nexon, Nexon America                100.0
# 9998  Electronic Arts, SlyGames, Taranau Aliaksei, R...                 80.0
# 9999      Valve, Buka Entertainment, NVIDIA, CyberFront                 98.0
#
#      steam_review_count       steam_review_label steam_price_text  \
# 0               56707.0          Mostly Positive            29.98
# 1              234151.0  Overwhelmingly Positive            29.99
# 2              169118.0  Overwhelmingly Positive             5.79
# 3             2513715.0            Very Positive             0.00
# 5              225402.0  Overwhelmingly Positive             5.79
# ...                 ...                      ...              ...
# 9994             1050.0            Very Positive             0.00
# 9995               95.0          Mostly Positive             3.60
# 9996               11.0                 Positive             2.63
# 9998               15.0                 Positive             2.64
# 9999            81012.0  Overwhelmingly Positive             5.07
#
#      steam_platform_flags                                    developers_list  \
# 0                     win                   [Rockstar North, Rockstar Games]
# 1                     win                                   [CD PROJEKT RED]
# 2              linux, win                                   [Valve Software]
# 3              linux, win        [Valve Software, Hidden Path Entertainment]
# 5              linux, win              [Valve Software, Turtle Rock Studios]
# ...                   ...                                                ...
# 9994           linux, win                                          [Empires]
# 9995                  win                                     [Monte Cristo]
# 9996                music                              [NEXON KOREA, devCAT]
# 9998             mac, win  [Electronic Arts, 1C Wireless, Taranau Aliakse...
# 9999           linux, win        [Valve Software, NVIDIA Lightspeed Studios]
#
#                                         publishers_list
# 0                                      [Rockstar Games]
# 1                                      [CD PROJEKT RED]
# 2                              [Electronic Arts, Valve]
# 3                                               [Valve]
# 5                      [Electronic Arts, Valve, Akella]
# ...                                                 ...
# 9994                                          [Empires]
# 9995                           [Focus Home Interactive]
# 9996                             [Nexon, Nexon America]
# 9998  [Electronic Arts, SlyGames, Taranau Aliaksei, ...
# 9999    [Valve, Buka Entertainment, NVIDIA, CyberFront]
#
# [7703 rows x 25 columns]

# %% [markdown]
# УДАЛИТЬ НЕАНГЛИЙСКИЕ ТЕГИ

# %%
def is_self_published(row):
    return len(set(row['developers_list']) & set(row['publishers_list'])) > 0

df['is_self_published'] = df.apply(is_self_published, axis=1)
df
# Out:
# /tmp/ipykernel_10659/1149722391.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_self_published'] = df.apply(is_self_published, axis=1)
#       Unnamed: 0                              name    released dataset_label  \
# 0              0                Grand Theft Auto V  2013-09-17      released
# 1              1          The Witcher 3: Wild Hunt  2015-05-18      released
# 2              2                          Portal 2  2011-04-18      released
# 3              3  Counter-Strike: Global Offensive  2012-08-21      released
# 5              5                     Left 4 Dead 2  2009-11-17      released
# ...          ...                               ...         ...           ...
# 9994        9994                       Empires Mod  2008-07-28      released
# 9995        9995       Silverfall: Earth Awakening  2008-07-18      released
# 9996        9996                          Mabinogi  2008-03-27      released
# 9998        9998                            Sudoku  2008-07-11      released
# 9999        9999                            Portal  2007-10-09      released
#
#       source_window                             slug  rating  ratings_count  \
# 0              2013               grand-theft-auto-v    4.47           7363
# 1              2015          the-witcher-3-wild-hunt    4.64           7178
# 2              2011                         portal-2    4.58           6086
# 3              2012  counter-strike-global-offensive    3.57           3634
# 5              2009                    left-4-dead-2    4.10           3407
# ...             ...                              ...     ...            ...
# 9994           2008                      empires-mod    1.64             11
# 9995           2008       silverfall-earth-awakening    3.00             16
# 9996           2008                         mabinogi    3.40             15
# 9998           2008                           sudoku    2.48             23
# 9999           2007                           portal    4.49           5007
#
#       reviews_count  playtime  ...  \
# 0              7499        74  ...
# 1              7297        43  ...
# 2              6143        11  ...
# 3              3671        64  ...
# 5              3434         9  ...
# ...             ...       ...  ...
# 9994             11         1  ...
# 9995             16         1  ...
# 9996             15         2  ...
# 9998             23         1  ...
# 9999           5052         4  ...
#
#                                              developers  \
# 0                        Rockstar North, Rockstar Games
# 1                                        CD PROJEKT RED
# 2                                        Valve Software
# 3             Valve Software, Hidden Path Entertainment
# 5                   Valve Software, Turtle Rock Studios
# ...                                                 ...
# 9994                                            Empires
# 9995                                       Monte Cristo
# 9996                                NEXON KOREA, devCAT
# 9998  Electronic Arts, 1C Wireless, Taranau Aliaksei...
# 9999          Valve Software, NVIDIA Lightspeed Studios
#
#                                              publishers steam_review_percent  \
# 0                                        Rockstar Games                 79.0
# 1                                        CD PROJEKT RED                 96.0
# 2                                Electronic Arts, Valve                 98.0
# 3                                                 Valve                 86.0
# 5                        Electronic Arts, Valve, Akella                 97.0
# ...                                                 ...                  ...
# 9994                                            Empires                 86.0
# 9995                             Focus Home Interactive                 72.0
# 9996                               Nexon, Nexon America                100.0
# 9998  Electronic Arts, SlyGames, Taranau Aliaksei, R...                 80.0
# 9999      Valve, Buka Entertainment, NVIDIA, CyberFront                 98.0
#
#      steam_review_count       steam_review_label steam_price_text  \
# 0               56707.0          Mostly Positive            29.98
# 1              234151.0  Overwhelmingly Positive            29.99
# 2              169118.0  Overwhelmingly Positive             5.79
# 3             2513715.0            Very Positive             0.00
# 5              225402.0  Overwhelmingly Positive             5.79
# ...                 ...                      ...              ...
# 9994             1050.0            Very Positive             0.00
# 9995               95.0          Mostly Positive             3.60
# 9996               11.0                 Positive             2.63
# 9998               15.0                 Positive             2.64
# 9999            81012.0  Overwhelmingly Positive             5.07
#
#      steam_platform_flags                                    developers_list  \
# 0                     win                   [Rockstar North, Rockstar Games]
# 1                     win                                   [CD PROJEKT RED]
# 2              linux, win                                   [Valve Software]
# 3              linux, win        [Valve Software, Hidden Path Entertainment]
# 5              linux, win              [Valve Software, Turtle Rock Studios]
# ...                   ...                                                ...
# 9994           linux, win                                          [Empires]
# 9995                  win                                     [Monte Cristo]
# 9996                music                              [NEXON KOREA, devCAT]
# 9998             mac, win  [Electronic Arts, 1C Wireless, Taranau Aliakse...
# 9999           linux, win        [Valve Software, NVIDIA Lightspeed Studios]
#
#                                         publishers_list  is_self_published
# 0                                      [Rockstar Games]               True
# 1                                      [CD PROJEKT RED]               True
# 2                              [Electronic Arts, Valve]              False
# 3                                               [Valve]              False
# 5                      [Electronic Arts, Valve, Akella]              False
# ...                                                 ...                ...
# 9994                                          [Empires]               True
# 9995                           [Focus Home Interactive]              False
# 9996                             [Nexon, Nexon America]              False
# 9998  [Electronic Arts, SlyGames, Taranau Aliaksei, ...               True
# 9999    [Valve, Buka Entertainment, NVIDIA, CyberFront]              False
#
# [7703 rows x 26 columns]

# %%
print(df.columns.tolist())
df['platforms'].unique()
# Out:
# ['Unnamed: 0', 'name', 'released', 'dataset_label', 'source_window', 'slug', 'rating', 'ratings_count', 'reviews_count', 'playtime', 'added', 'suggestions_count', 'genres', 'tags', 'platforms', 'stores', 'developers', 'publishers', 'steam_review_percent', 'steam_review_count', 'steam_review_label', 'steam_price_text', 'steam_platform_flags', 'developers_list', 'publishers_list', 'is_self_published']
# array(['PlayStation 5, Xbox Series S/X, PlayStation 3, PC, PlayStation 4, Xbox 360, Xbox One',
#        'PlayStation 5, Xbox Series S/X, macOS, PlayStation 4, Nintendo Switch, PC, Xbox One',
#        'PlayStation 3, PC, Xbox 360, Linux, macOS, Xbox One', ...,
#        'PlayStation 4, Wii, Nintendo Switch, PC, Xbox One',
#        'PC, PlayStation 3, PSP, Nintendo DS, iOS, Android, macOS, Linux',
#        'macOS, PC, Android, PlayStation 3, Xbox 360, Linux, Nintendo Switch'],
#       dtype=object)

# %%
df['has_win'] = df['steam_platform_flags'].str.contains('win')
df['has_mac'] = df['steam_platform_flags'].str.contains('mac')
df['has_linux'] = df['steam_platform_flags'].str.contains('linux')
df['has_ps'] =  (df['platforms'].str.contains('PlayStation 5') | df['platforms'].str.contains('PlayStation 4') | df['platforms'].str.contains('PlayStation 3'))
df['has_Nintendo'] =  df['platforms'].str.contains('Nintendo Switch')
# Out:
# /tmp/ipykernel_10659/3967816357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['has_win'] = df['steam_platform_flags'].str.contains('win')
# /tmp/ipykernel_10659/3967816357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['has_mac'] = df['steam_platform_flags'].str.contains('mac')
# /tmp/ipykernel_10659/3967816357.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['has_linux'] = df['steam_platform_flags'].str.contains('linux')
# /tmp/ipykernel_10659/3967816357.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['has_ps'] =  (df['platforms'].str.contains('PlayStation 5') | df['platforms'].str.contains('PlayStation 4') | df['platforms'].str.contains('PlayStation 3'))
# /tmp/ipykernel_10659/3967816357.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['has_Nintendo'] =  df['platforms'].str.contains('Nintendo Switch')

# %%
df
# Out:
#       Unnamed: 0                              name    released dataset_label  \
# 0              0                Grand Theft Auto V  2013-09-17      released
# 1              1          The Witcher 3: Wild Hunt  2015-05-18      released
# 2              2                          Portal 2  2011-04-18      released
# 3              3  Counter-Strike: Global Offensive  2012-08-21      released
# 5              5                     Left 4 Dead 2  2009-11-17      released
# ...          ...                               ...         ...           ...
# 9994        9994                       Empires Mod  2008-07-28      released
# 9995        9995       Silverfall: Earth Awakening  2008-07-18      released
# 9996        9996                          Mabinogi  2008-03-27      released
# 9998        9998                            Sudoku  2008-07-11      released
# 9999        9999                            Portal  2007-10-09      released
#
#       source_window                             slug  rating  ratings_count  \
# 0              2013               grand-theft-auto-v    4.47           7363
# 1              2015          the-witcher-3-wild-hunt    4.64           7178
# 2              2011                         portal-2    4.58           6086
# 3              2012  counter-strike-global-offensive    3.57           3634
# 5              2009                    left-4-dead-2    4.10           3407
# ...             ...                              ...     ...            ...
# 9994           2008                      empires-mod    1.64             11
# 9995           2008       silverfall-earth-awakening    3.00             16
# 9996           2008                         mabinogi    3.40             15
# 9998           2008                           sudoku    2.48             23
# 9999           2007                           portal    4.49           5007
#
#       reviews_count  playtime  ...  steam_price_text  steam_platform_flags  \
# 0              7499        74  ...             29.98                   win
# 1              7297        43  ...             29.99                   win
# 2              6143        11  ...              5.79            linux, win
# 3              3671        64  ...              0.00            linux, win
# 5              3434         9  ...              5.79            linux, win
# ...             ...       ...  ...               ...                   ...
# 9994             11         1  ...              0.00            linux, win
# 9995             16         1  ...              3.60                   win
# 9996             15         2  ...              2.63                 music
# 9998             23         1  ...              2.64              mac, win
# 9999           5052         4  ...              5.07            linux, win
#
#                                         developers_list  \
# 0                      [Rockstar North, Rockstar Games]
# 1                                      [CD PROJEKT RED]
# 2                                      [Valve Software]
# 3           [Valve Software, Hidden Path Entertainment]
# 5                 [Valve Software, Turtle Rock Studios]
# ...                                                 ...
# 9994                                          [Empires]
# 9995                                     [Monte Cristo]
# 9996                              [NEXON KOREA, devCAT]
# 9998  [Electronic Arts, 1C Wireless, Taranau Aliakse...
# 9999        [Valve Software, NVIDIA Lightspeed Studios]
#
#                                         publishers_list is_self_published  \
# 0                                      [Rockstar Games]              True
# 1                                      [CD PROJEKT RED]              True
# 2                              [Electronic Arts, Valve]             False
# 3                                               [Valve]             False
# 5                      [Electronic Arts, Valve, Akella]             False
# ...                                                 ...               ...
# 9994                                          [Empires]              True
# 9995                           [Focus Home Interactive]             False
# 9996                             [Nexon, Nexon America]             False
# 9998  [Electronic Arts, SlyGames, Taranau Aliaksei, ...              True
# 9999    [Valve, Buka Entertainment, NVIDIA, CyberFront]             False
#
#      has_win has_mac has_linux  has_ps  has_Nintendo
# 0       True   False     False    True         False
# 1       True   False     False    True          True
# 2       True   False      True    True         False
# 3       True   False      True    True         False
# 5       True   False      True   False         False
# ...      ...     ...       ...     ...           ...
# 9994    True   False      True   False         False
# 9995    True   False     False   False         False
# 9996   False   False     False   False         False
# 9998    True    True     False    True         False
# 9999    True   False      True    True          True
#
# [7703 rows x 31 columns]

# %%
plt.hist(df['source_window'],bins=50)
plt.xticks(range(2008, 2027, 1), rotation=90)
plt.xlim(2007,2027)
# Out:
# (2007.0, 2027.0)

# %% [markdown]
# можно заметить что наиболее распространенный год выпуска в данных(глобальный максимум) - 2016

# %%
lol = df.copy()
lol['genres'] = lol['genres'].str.split(', ')
df_exploded = lol.explode('genres')
table = df_exploded.groupby('genres').size().sort_values(ascending=False)
table.sort_values(ascending=False).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='genres'>

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
print(f'Windows поддерживает {np.round(len(df[df['has_win'] == True]) / len(df), 2) * 100}% игр')
print(f'Mac OS поддерживает {np.round(len(df[df['has_mac'] == True]) / len(df), 2) * 100}% игр')
print(f'Linux поддерживает {np.round(len(df[df['has_linux'] == True]) / len(df), 2) * 100}% игр')
print(f'PS поддерживает {np.round(len(df[df['has_ps'] == True]) / len(df), 2) * 100}% игр')
print(f'Nintendo поддерживает {np.round(len(df[df['has_Nintendo'] == True]) / len(df), 2) * 100}% игр')
# Out:
# Windows поддерживает 100.0% игр
# Mac OS поддерживает 39.0% игр
# Linux поддерживает 27.0% игр
# PS поддерживает 35.0% игр
# Nintendo поддерживает 24.0% игр

# %%
df_lin = df[df['has_linux'] == True].copy()
df_mac = df[df['has_mac'] == True].copy()

# %%
df1 = df_exploded[df_exploded['steam_review_count']>100]
df2 = df_exploded[df_exploded['steam_review_count']<100]

# %%
df_exploded['genres'].unique()
# Out:
# array(['Action', 'RPG', 'Shooter', 'Puzzle', 'Adventure', 'Indie',
#        'Platformer', 'Massively Multiplayer', 'Simulation', 'Arcade',
#        'Strategy', 'Fighting', 'Family', 'Casual', 'Racing',
#        'Educational', 'Sports', 'Card', 'Board Games'], dtype=object)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16, 5))
table = df1.groupby('genres')['steam_review_percent'].median().reset_index()
table = table.sort_values('steam_review_percent', ascending=False)
ax1.bar(table['genres'], table['steam_review_percent'])
ax1.tick_params(axis='x', labelrotation=90)
table2 = df1.groupby('genres')['rating'].mean().reset_index()
table2 = table2.sort_values('rating', ascending=False)
ax2.bar(table2['genres'], table2['rating'])
ax2.tick_params(axis='x', labelrotation=90)

# %%
table2 = df2.groupby('genres')['steam_review_percent'].mean()
table2.sort_values(ascending=False).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='genres'>

# %%
loly = df.copy()
loly['tags'] = loly['tags'].str.split(', ')
df3_exploded = loly.explode('tags')
gg = df3_exploded.groupby('tags').size().sort_values(ascending=False)
newgg = gg[(gg > 100)&(gg < 5000)].index.values
newdf8 = df3_exploded[df3_exploded['tags'].isin(newgg)]
gg1 = newdf8.groupby('tags').size().sort_values(ascending=False)
gg1
# Out:
# tags
# Steam Cloud                3334
# Full controller support    3089
# steam-trading-cards        2387
# Multiplayer                2244
# 2D                         2021
#                            ...
# battle                      105
# Blood                       104
# Noir                        103
# Score Attack                103
# 1980s                       101
# Length: 194, dtype: int64

# %%
df1_tags = df3_exploded[df3_exploded['steam_review_count']>200]
df2_tags = df3_exploded[df3_exploded['steam_review_count']<200]
tagtable = df1_tags.groupby('tags')['steam_review_percent'].median()
tagtable.sort_values(ascending=False).head(15).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='tags'>

# %%
tagtable = df1_tags.groupby('tags')['rating'].median()
tagtable.sort_values(ascending=False).head(15).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='tags'>

# %% [markdown]
# Clown очень странный тег

# %%
tag2table = df2_tags.groupby('tags')['steam_review_percent'].median()
tag2table.sort_values(ascending=False).head(15).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='tags'>

# %%
tag2table.sort_values(ascending=False).tail(15).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='tags'>

# %%
df3_exploded['tags'].value_counts().head(20)
# Out:
# tags
# Singleplayer                  7258
# Steam Achievements            5083
# Steam Cloud                   3334
# Full controller support       3089
# steam-trading-cards           2387
# Multiplayer                   2244
# 2D                            2021
# Atmospheric                   1896
# RPG                           1885
# Story Rich                    1535
# Co-op                         1397
# Great Soundtrack              1345
# Horror                        1262
# Partial Controller Support    1214
# First-Person                  1125
# cooperative                   1084
# Exploration                   1050
# Steam Leaderboards            1035
# Pixel Graphics                 991
# Open World                     970
# Name: count, dtype: int64

# %%
open_world_df = df3_exploded[df3_exploded['tags'] == 'Open World']

# %%
dfg = df_exploded.copy()
dfg1 = dfg[dfg['has_linux'] == True]
dfg2 = dfg[dfg['has_mac'] == True]
dfg3 = dfg[(dfg['has_mac'] == False)& (dfg['has_linux'] == False) & (dfg['has_win'] == True)]

# %%
dfg1['steam_review_percent'].median()
dfg1['steam_review_percent'].mean()
# Out:
# np.float64(82.6166351010101)

# %%
dfg2['steam_review_percent'].median()
dfg2['steam_review_percent'].mean()
# Out:
# np.float64(82.72784607161945)

# %%
dfg3['steam_review_percent'].median()
dfg3['steam_review_percent'].mean()
# Out:
# np.float64(79.13812730479397)

# %%
tablez = dfg1.groupby('genres').size()
tablez.sort_values(ascending=False).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='genres'>

# %%
tablez = dfg2.groupby('genres').size()
tablez.sort_values(ascending=False).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='genres'>

# %%
tablez = dfg3.groupby('genres').size()
tablez.sort_values(ascending=False).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='genres'>

# %%
tablez = dfg3.groupby('genres').size()
tablez.sort_values(ascending=False).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='genres'>

# %% [markdown]
# анализ по компаниям

# %%
df
# Out:
#       Unnamed: 0                              name    released dataset_label  \
# 0              0                Grand Theft Auto V  2013-09-17      released
# 1              1          The Witcher 3: Wild Hunt  2015-05-18      released
# 2              2                          Portal 2  2011-04-18      released
# 3              3  Counter-Strike: Global Offensive  2012-08-21      released
# 5              5                     Left 4 Dead 2  2009-11-17      released
# ...          ...                               ...         ...           ...
# 9994        9994                       Empires Mod  2008-07-28      released
# 9995        9995       Silverfall: Earth Awakening  2008-07-18      released
# 9996        9996                          Mabinogi  2008-03-27      released
# 9998        9998                            Sudoku  2008-07-11      released
# 9999        9999                            Portal  2007-10-09      released
#
#       source_window                             slug  rating  ratings_count  \
# 0              2013               grand-theft-auto-v    4.47           7363
# 1              2015          the-witcher-3-wild-hunt    4.64           7178
# 2              2011                         portal-2    4.58           6086
# 3              2012  counter-strike-global-offensive    3.57           3634
# 5              2009                    left-4-dead-2    4.10           3407
# ...             ...                              ...     ...            ...
# 9994           2008                      empires-mod    1.64             11
# 9995           2008       silverfall-earth-awakening    3.00             16
# 9996           2008                         mabinogi    3.40             15
# 9998           2008                           sudoku    2.48             23
# 9999           2007                           portal    4.49           5007
#
#       reviews_count  playtime  ...  steam_price_text  steam_platform_flags  \
# 0              7499        74  ...             29.98                   win
# 1              7297        43  ...             29.99                   win
# 2              6143        11  ...              5.79            linux, win
# 3              3671        64  ...              0.00            linux, win
# 5              3434         9  ...              5.79            linux, win
# ...             ...       ...  ...               ...                   ...
# 9994             11         1  ...              0.00            linux, win
# 9995             16         1  ...              3.60                   win
# 9996             15         2  ...              2.63                 music
# 9998             23         1  ...              2.64              mac, win
# 9999           5052         4  ...              5.07            linux, win
#
#                                         developers_list  \
# 0                      [Rockstar North, Rockstar Games]
# 1                                      [CD PROJEKT RED]
# 2                                      [Valve Software]
# 3           [Valve Software, Hidden Path Entertainment]
# 5                 [Valve Software, Turtle Rock Studios]
# ...                                                 ...
# 9994                                          [Empires]
# 9995                                     [Monte Cristo]
# 9996                              [NEXON KOREA, devCAT]
# 9998  [Electronic Arts, 1C Wireless, Taranau Aliakse...
# 9999        [Valve Software, NVIDIA Lightspeed Studios]
#
#                                         publishers_list is_self_published  \
# 0                                      [Rockstar Games]              True
# 1                                      [CD PROJEKT RED]              True
# 2                              [Electronic Arts, Valve]             False
# 3                                               [Valve]             False
# 5                      [Electronic Arts, Valve, Akella]             False
# ...                                                 ...               ...
# 9994                                          [Empires]              True
# 9995                           [Focus Home Interactive]             False
# 9996                             [Nexon, Nexon America]             False
# 9998  [Electronic Arts, SlyGames, Taranau Aliaksei, ...              True
# 9999    [Valve, Buka Entertainment, NVIDIA, CyberFront]             False
#
#      has_win has_mac has_linux  has_ps  has_Nintendo
# 0       True   False     False    True         False
# 1       True   False     False    True          True
# 2       True   False      True    True         False
# 3       True   False      True    True         False
# 5       True   False      True   False         False
# ...      ...     ...       ...     ...           ...
# 9994    True   False      True   False         False
# 9995    True   False     False   False         False
# 9996   False   False     False   False         False
# 9998    True    True     False    True         False
# 9999    True   False      True    True          True
#
# [7703 rows x 31 columns]

# %%
companydf = df.copy()
company_exploded = companydf.explode('publishers_list')
cc = company_exploded.groupby('publishers_list').size().sort_values(ascending=False)
newcc = cc[(cc > 50)].index.values
newdf10 = company_exploded[company_exploded['publishers_list'].isin(newcc)]
gg4 = newdf10.groupby('publishers_list').size().sort_values(ascending=False)
gg4
# Out:
# publishers_list
# Devolver Digital              115
# THQ Nordic                     97
# Bandai Namco Entertainment     96
# Plug In Digital                72
# Focus Home Interactive         69
# Daedalic Entertainment         65
# tinyBuild                      64
# SEGA                           63
# Ubisoft Entertainment          59
# Electronic Arts                58
# Kiss                           57
# 505 Games                      53
# Square Enix                    53
# Microsoft Studios              51
# dtype: int64

# %%
df1_comp = company_exploded[company_exploded['steam_review_count']>100 & (company_exploded['genres'].str.contains('platformer'))]
comptable = df1_comp.groupby('publishers_list')['steam_review_percent'].median()
comptable.sort_values(ascending=False).head(15).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='publishers_list'>

# %%
df4_comp = company_exploded[(company_exploded['genres'].str.contains('RPG'))]
comptable = df4_comp.groupby('publishers_list')['steam_review_percent'].median()
comptable.sort_values(ascending=False).head(15).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='publishers_list'>

# %%
data5 = company_exploded[company_exploded['publishers_list'].str.contains('Devolver Digital', na=False)]
data5.plot.scatter(x='steam_review_percent', y='steam_review_count', alpha=0.7, s=40, c='darkblue', edgecolors='white', figsize=(6,4))
plt.title('Зависимость оценки от кол-ва отзывов у Devolver Digital')
plt.xlabel('steam_review_percent')
plt.ylabel('steam_review_count')
# Out:
# Text(0, 0.5, 'steam_review_count')

# %%
data5 = company_exploded[company_exploded['publishers_list'].str.contains('THQ Nordic', na=False)]
data5.plot.scatter(x='steam_review_percent', y='steam_review_count', alpha=0.7, s=40, c='darkblue', edgecolors='white', figsize=(6,4))
plt.title('Зависимость оценки от кол-ва отзывов у THQ Nordic')
plt.xlabel('steam_review_percent')
plt.ylabel('steam_review_count')
# Out:
# Text(0, 0.5, 'steam_review_count')

# %%
cc = company_exploded.groupby('publishers_list')['steam_review_percent'].mean().sort_values(ascending=False)
cc[cc.isin(gg4)]
# Out:
# publishers_list
# eduweb                 97.0
# Madison Karrh          97.0
# SteelRaven7            97.0
# mino_dev               97.0
# npckc                  97.0
#                        ...
# CraftsmanGames         51.0
# UKKIM                  51.0
# Zero Point Software    51.0
# ParadoxInteractive     51.0
# EpicQuest Games        51.0
# Name: steam_review_percent, Length: 470, dtype: float64

# %%
df_long = df[df['playtime'] > 10]

# %%
df_long['genres'] = df_long['genres'].apply(lambda x: x.split(','))
# Out:
# /tmp/ipykernel_10659/3197330185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_long['genres'] = df_long['genres'].apply(lambda x: x.split(','))

# %%
df_long = df_long.explode('genres')
df_long['genres'] = df_long['genres'].apply(lambda x: x.strip().lower())

# %%
df_long = df_long[df_long['steam_review_count'] > 100]
df_long
# Out:
#       Unnamed: 0                      name    released dataset_label  \
# 0              0        Grand Theft Auto V  2013-09-17      released
# 1              1  The Witcher 3: Wild Hunt  2015-05-18      released
# 1              1  The Witcher 3: Wild Hunt  2015-05-18      released
# 2              2                  Portal 2  2011-04-18      released
# 2              2                  Portal 2  2011-04-18      released
# ...          ...                       ...         ...           ...
# 9596        9596              Tower Wizard  2025-06-19      released
# 9658        9658              Dark Deity 2  2025-03-23      released
# 9658        9658              Dark Deity 2  2025-03-23      released
# 9658        9658              Dark Deity 2  2025-03-23      released
# 9658        9658              Dark Deity 2  2025-03-23      released
#
#       source_window                     slug  rating  ratings_count  \
# 0              2013       grand-theft-auto-v    4.47           7363
# 1              2015  the-witcher-3-wild-hunt    4.64           7178
# 1              2015  the-witcher-3-wild-hunt    4.64           7178
# 2              2011                 portal-2    4.58           6086
# 2              2011                 portal-2    4.58           6086
# ...             ...                      ...     ...            ...
# 9596           2025           tower-wizard-2    0.00              3
# 9658           2025             dark-deity-2    0.00              1
# 9658           2025             dark-deity-2    0.00              1
# 9658           2025             dark-deity-2    0.00              1
# 9658           2025             dark-deity-2    0.00              1
#
#       reviews_count  playtime  ...  steam_price_text  steam_platform_flags  \
# 0              7499        74  ...             29.98                   win
# 1              7297        43  ...             29.99                   win
# 1              7297        43  ...             29.99                   win
# 2              6143        11  ...              5.79            linux, win
# 2              6143        11  ...              5.79            linux, win
# ...             ...       ...  ...               ...                   ...
# 9596              4        12  ...              1.64                   win
# 9658              1        31  ...             14.45                   win
# 9658              1        31  ...             14.45                   win
# 9658              1        31  ...             14.45                   win
# 9658              1        31  ...             14.45                   win
#
#                        developers_list           publishers_list  \
# 0     [Rockstar North, Rockstar Games]          [Rockstar Games]
# 1                     [CD PROJEKT RED]          [CD PROJEKT RED]
# 1                     [CD PROJEKT RED]          [CD PROJEKT RED]
# 2                     [Valve Software]  [Electronic Arts, Valve]
# 2                     [Valve Software]  [Electronic Arts, Valve]
# ...                                ...                       ...
# 9596                        [Barribob]                [Barribob]
# 9658         [Sword & Axe, Sword, Axe]     [indie.io, SmileGate]
# 9658         [Sword & Axe, Sword, Axe]     [indie.io, SmileGate]
# 9658         [Sword & Axe, Sword, Axe]     [indie.io, SmileGate]
# 9658         [Sword & Axe, Sword, Axe]     [indie.io, SmileGate]
#
#      is_self_published has_win has_mac has_linux  has_ps  has_Nintendo
# 0                 True    True   False     False    True         False
# 1                 True    True   False     False    True          True
# 1                 True    True   False     False    True          True
# 2                False    True   False      True    True         False
# 2                False    True   False      True    True         False
# ...                ...     ...     ...       ...     ...           ...
# 9596              True    True   False     False   False         False
# 9658             False    True   False     False   False         False
# 9658             False    True   False     False   False         False
# 9658             False    True   False     False   False         False
# 9658             False    True   False     False   False         False
#
# [647 rows x 31 columns]

# %%
df_long.groupby('genres')[['rating', 'steam_review_percent']].count().reset_index()
# Out:
#                    genres  rating  steam_review_percent
# 0                  action     152                   152
# 1               adventure     101                   101
# 2                  arcade       3                     3
# 3                    card       1                     1
# 4                  casual      26                    26
# 5             educational       1                     1
# 6                  family       1                     1
# 7                fighting       4                     4
# 8                   indie      71                    71
# 9   massively multiplayer      15                    15
# 10             platformer       5                     5
# 11                 puzzle       5                     5
# 12                 racing       7                     7
# 13                    rpg     110                   110
# 14                shooter      36                    36
# 15             simulation      54                    54
# 16                 sports       8                     8
# 17               strategy      47                    47

# %%
df_long = df_long[(df_long['genres'] != 'card') & (df_long['genres'] != 'arcade') & (df_long['genres'] != 'educational') &
(df_long['genres'] != 'family') & (df_long['genres'] != 'fighting')]

# %%
df_gol = df_long.groupby('genres')[['rating', 'steam_review_percent']].median().reset_index()
df_gol
# Out:
#                    genres  rating  steam_review_percent
# 0                  action   3.910                  88.0
# 1               adventure   3.830                  88.0
# 2                  casual   3.620                  92.0
# 3                   indie   3.670                  92.0
# 4   massively multiplayer   3.400                  77.0
# 5              platformer   4.360                  96.0
# 6                  puzzle   4.260                  95.0
# 7                  racing   3.320                  76.0
# 8                     rpg   3.910                  90.0
# 9                 shooter   3.880                  86.0
# 10             simulation   3.500                  87.5
# 11                 sports   3.385                  76.5
# 12               strategy   3.640                  87.0

# %%
df_gol = df_gol.sort_values('steam_review_percent', ascending=False)
df_gol1 = df_gol.sort_values('rating', ascending=False)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16, 5))
ax1.bar(df_gol['genres'], df_gol['steam_review_percent'])
ax1.tick_params(axis='x', labelrotation=90)
ax2.bar(df_gol1['genres'], df_gol1['rating'])
ax2.tick_params(axis='x', labelrotation=90)

# %%
df_short = df[df['playtime'] < 10]
df_short['genres'] = df_short['genres'].apply(lambda x: x.split(','))
df_short = df_short.explode('genres')
df_short['genres'] = df_short['genres'].apply(lambda x: x.strip().lower())
df_short = df_short[df_short['steam_review_count'] > 100]
df_short
# Out:
# /tmp/ipykernel_10659/1755802302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_short['genres'] = df_short['genres'].apply(lambda x: x.split(','))
#       Unnamed: 0             name    released dataset_label  source_window  \
# 5              5    Left 4 Dead 2  2009-11-17      released           2009
# 5              5    Left 4 Dead 2  2009-11-17      released           2009
# 10            10  Life is Strange  2015-01-29      released           2015
# 11            11        Destiny 2  2017-09-06      released           2017
# 11            11        Destiny 2  2017-09-06      released           2017
# ...          ...              ...         ...           ...            ...
# 9993        9993          Warfare  2008-09-19      released           2008
# 9994        9994      Empires Mod  2008-07-28      released           2008
# 9994        9994      Empires Mod  2008-07-28      released           2008
# 9999        9999           Portal  2007-10-09      released           2007
# 9999        9999           Portal  2007-10-09      released           2007
#
#                              slug  rating  ratings_count  reviews_count  \
# 5                   left-4-dead-2    4.10           3407           3434
# 5                   left-4-dead-2    4.10           3407           3434
# 10    life-is-strange-episode-1-2    4.12           3768           3815
# 11                      destiny-2    3.52           2668           2694
# 11                      destiny-2    3.52           2668           2694
# ...                           ...     ...            ...            ...
# 9993                      warfare    3.40             10             10
# 9994                  empires-mod    1.64             11             11
# 9994                  empires-mod    1.64             11             11
# 9999                       portal    4.49           5007           5052
# 9999                       portal    4.49           5007           5052
#
#       playtime  ...  steam_price_text  steam_platform_flags  \
# 5            9  ...              5.79            linux, win
# 5            9  ...              5.79            linux, win
# 10           6  ...              0.00       linux, mac, win
# 11           6  ...              0.00                   win
# 11           6  ...              0.00                   win
# ...        ...  ...               ...                   ...
# 9993         1  ...              3.80                   win
# 9994         1  ...              0.00            linux, win
# 9994         1  ...              0.00            linux, win
# 9999         4  ...              5.07            linux, win
# 9999         4  ...              5.07            linux, win
#
#                                   developers_list  \
# 5           [Valve Software, Turtle Rock Studios]
# 5           [Valve Software, Turtle Rock Studios]
# 10                        [DONTNOD Entertainment]
# 11                                       [Bungie]
# 11                                       [Bungie]
# ...                                           ...
# 9993                                 [GFI Russia]
# 9994                                    [Empires]
# 9994                                    [Empires]
# 9999  [Valve Software, NVIDIA Lightspeed Studios]
# 9999  [Valve Software, NVIDIA Lightspeed Studios]
#
#                                       publishers_list is_self_published  \
# 5                    [Electronic Arts, Valve, Akella]             False
# 5                    [Electronic Arts, Valve, Akella]             False
# 10                   [Square Enix, Feral Interactive]             False
# 11                      [Activision Blizzard, Bungie]              True
# 11                      [Activision Blizzard, Bungie]              True
# ...                                               ...               ...
# 9993                       [Game Factory Interactive]             False
# 9994                                        [Empires]              True
# 9994                                        [Empires]              True
# 9999  [Valve, Buka Entertainment, NVIDIA, CyberFront]             False
# 9999  [Valve, Buka Entertainment, NVIDIA, CyberFront]             False
#
#      has_win has_mac has_linux  has_ps  has_Nintendo
# 5       True   False      True   False         False
# 5       True   False      True   False         False
# 10      True    True      True    True         False
# 11      True   False     False    True         False
# 11      True   False     False    True         False
# ...      ...     ...       ...     ...           ...
# 9993    True   False     False   False         False
# 9994    True   False      True   False         False
# 9994    True   False      True   False         False
# 9999    True   False      True    True          True
# 9999    True   False      True    True          True
#
# [19263 rows x 31 columns]

# %%
df_short.groupby('genres')[['rating', 'steam_review_percent']].count().reset_index()
# Out:
#                    genres  rating  steam_review_percent
# 0                  action    3244                  3244
# 1               adventure    3125                  3125
# 2                  arcade     256                   256
# 3             board games      47                    47
# 4                    card      56                    56
# 5                  casual    1628                  1628
# 6             educational      42                    42
# 7                  family      82                    82
# 8                fighting      90                    90
# 9                   indie    4361                  4361
# 10  massively multiplayer     216                   216
# 11             platformer     269                   269
# 12                 puzzle     530                   530
# 13                 racing     259                   259
# 14                    rpg    1545                  1545
# 15                shooter     328                   328
# 16             simulation    1442                  1442
# 17                 sports     240                   240
# 18               strategy    1503                  1503

# %%
df_gol = df_short.groupby('genres')[['rating', 'steam_review_percent']].median().reset_index()
df_gol
# Out:
#                    genres  rating  steam_review_percent
# 0                  action   3.290                  84.0
# 1               adventure   3.430                  85.0
# 2                  arcade   3.360                  86.0
# 3             board games   3.370                  83.0
# 4                    card   3.560                  84.5
# 5                  casual   3.285                  87.0
# 6             educational   3.425                  88.0
# 7                  family   3.615                  87.5
# 8                fighting   3.575                  83.5
# 9                   indie   3.330                  86.0
# 10  massively multiplayer   2.755                  72.0
# 11             platformer   3.620                  89.0
# 12                 puzzle   3.570                  89.0
# 13                 racing   3.030                  80.0
# 14                    rpg   3.290                  82.0
# 15                shooter   3.410                  83.0
# 16             simulation   3.320                  83.0
# 17                 sports   3.000                  82.0
# 18               strategy   3.190                  82.0

# %%
df_gol = df_gol.sort_values('steam_review_percent', ascending=False)
df_gol1 = df_gol.sort_values('rating', ascending=False)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16, 5))
ax1.bar(df_gol['genres'], df_gol['steam_review_percent'])
ax1.tick_params(axis='x', labelrotation=90)
ax2.bar(df_gol1['genres'], df_gol1['rating'])
ax2.tick_params(axis='x', labelrotation=90)

# %%
df_pr = df[df['steam_price_text'] < 80]

# %%
def set_price_category(s):
    if s == 0:
        return 'Free'
    if s < 5:
        return 'One guy job'
    if s < 15:
        return 'Small budget'
    if s < 29:
        return 'Middle budget'
    if s < 40:
        return 'AA'
    else:
        return 'AAA'

# %%
df_pr['Price_categorie'] = df_pr['steam_price_text'].apply(set_price_category)
df_pr['Price_categorie'].value_counts()
# Out:
# /tmp/ipykernel_10659/1157116780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pr['Price_categorie'] = df_pr['steam_price_text'].apply(set_price_category)
# Price_categorie
# Small budget     3238
# One guy job      2495
# Free             1000
# Middle budget     649
# AA                208
# AAA               110
# Name: count, dtype: int64

# %%
df_pr = df_pr[df_pr['steam_review_count'] > 100]

# %%
df_gol = df_pr.groupby('Price_categorie')[['rating', 'steam_review_percent', 'playtime']].median().reset_index()
df_gol
# Out:
#   Price_categorie  rating  steam_review_percent  playtime
# 0              AA   3.705                  82.5       5.0
# 1             AAA   3.845                  84.0       7.0
# 2            Free   2.810                  83.0       1.0
# 3   Middle budget   3.570                  83.5       4.0
# 4     One guy job   3.220                  85.0       3.0
# 5    Small budget   3.500                  86.0       3.0

# %%
df_gol = df_gol.sort_values('steam_review_percent', ascending=False)
df_gol1 = df_gol.sort_values('rating', ascending=False)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (16, 5))
ax1.bar(df_gol['Price_categorie'], df_gol['steam_review_percent'])
ax1.tick_params(axis='x', labelrotation=90)
ax2.bar(df_gol1['Price_categorie'], df_gol1['rating'])
ax2.tick_params(axis='x', labelrotation=90)
ax3.bar(df_gol1['Price_categorie'], df_gol1['playtime'])
ax3.tick_params(axis='x', labelrotation=90)

# %%
df_mult = df.copy()

# %%
df_mult = df_mult[df_mult['tags'].str.contains('Multiplayer')]
df_mult
# Out:
#       Unnamed: 0                              name    released dataset_label  \
# 0              0                Grand Theft Auto V  2013-09-17      released
# 2              2                          Portal 2  2011-04-18      released
# 3              3  Counter-Strike: Global Offensive  2012-08-21      released
# 5              5                     Left 4 Dead 2  2009-11-17      released
# 7              7             Red Dead Redemption 2  2018-10-26      released
# ...          ...                               ...         ...           ...
# 9981        9981                           de Blob  2008-09-22      released
# 9982        9982           Guilty Gear 2: Overture  2008-10-09      released
# 9994        9994                       Empires Mod  2008-07-28      released
# 9995        9995       Silverfall: Earth Awakening  2008-07-18      released
# 9996        9996                          Mabinogi  2008-03-27      released
#
#       source_window                             slug  rating  ratings_count  \
# 0              2013               grand-theft-auto-v    4.47           7363
# 2              2011                         portal-2    4.58           6086
# 3              2012  counter-strike-global-offensive    3.57           3634
# 5              2009                    left-4-dead-2    4.10           3407
# 7              2018            red-dead-redemption-2    4.59           5473
# ...             ...                              ...     ...            ...
# 9981           2008                          de-blob    3.86             42
# 9982           2008           guilty-gear-2-overture    3.00             13
# 9994           2008                      empires-mod    1.64             11
# 9995           2008       silverfall-earth-awakening    3.00             16
# 9996           2008                         mabinogi    3.40             15
#
#       reviews_count  playtime  ...  steam_price_text  steam_platform_flags  \
# 0              7499        74  ...             29.98                   win
# 2              6143        11  ...              5.79            linux, win
# 3              3671        64  ...              0.00            linux, win
# 5              3434         9  ...              5.79            linux, win
# 7              5605        21  ...             59.96                   win
# ...             ...       ...  ...               ...                   ...
# 9981             42         1  ...              7.88                   win
# 9982             13         3  ...              5.51                   win
# 9994             11         1  ...              0.00            linux, win
# 9995             16         1  ...              3.60                   win
# 9996             15         2  ...              2.63                 music
#
#                                   developers_list  \
# 0                [Rockstar North, Rockstar Games]
# 2                                [Valve Software]
# 3     [Valve Software, Hidden Path Entertainment]
# 5           [Valve Software, Turtle Rock Studios]
# 7                                [Rockstar Games]
# ...                                           ...
# 9981      [THQ Nordic, Blue Tongue Entertainment]
# 9982                           [Arc System Works]
# 9994                                    [Empires]
# 9995                               [Monte Cristo]
# 9996                        [NEXON KOREA, devCAT]
#
#                        publishers_list is_self_published has_win has_mac  \
# 0                     [Rockstar Games]              True    True   False
# 2             [Electronic Arts, Valve]             False    True   False
# 3                              [Valve]             False    True   False
# 5     [Electronic Arts, Valve, Akella]             False    True   False
# 7                     [Rockstar Games]              True    True   False
# ...                                ...               ...     ...     ...
# 9981   [THQ Nordic, THQ, Nordic Games]              True    True   False
# 9982   [Aksys Games, Arc System Works]              True    True   False
# 9994                         [Empires]              True    True   False
# 9995          [Focus Home Interactive]             False    True   False
# 9996            [Nexon, Nexon America]             False   False   False
#
#      has_linux  has_ps  has_Nintendo
# 0        False    True         False
# 2         True    True         False
# 3         True    True         False
# 5         True   False         False
# 7        False    True         False
# ...        ...     ...           ...
# 9981     False    True          True
# 9982     False   False         False
# 9994      True   False         False
# 9995     False   False         False
# 9996     False   False         False
#
# [2348 rows x 31 columns]

# %%
df_mult['Price_categorie'] = df_mult['steam_price_text'].apply(set_price_category)
df_mult
# Out:
#       Unnamed: 0                              name    released dataset_label  \
# 0              0                Grand Theft Auto V  2013-09-17      released
# 2              2                          Portal 2  2011-04-18      released
# 3              3  Counter-Strike: Global Offensive  2012-08-21      released
# 5              5                     Left 4 Dead 2  2009-11-17      released
# 7              7             Red Dead Redemption 2  2018-10-26      released
# ...          ...                               ...         ...           ...
# 9981        9981                           de Blob  2008-09-22      released
# 9982        9982           Guilty Gear 2: Overture  2008-10-09      released
# 9994        9994                       Empires Mod  2008-07-28      released
# 9995        9995       Silverfall: Earth Awakening  2008-07-18      released
# 9996        9996                          Mabinogi  2008-03-27      released
#
#       source_window                             slug  rating  ratings_count  \
# 0              2013               grand-theft-auto-v    4.47           7363
# 2              2011                         portal-2    4.58           6086
# 3              2012  counter-strike-global-offensive    3.57           3634
# 5              2009                    left-4-dead-2    4.10           3407
# 7              2018            red-dead-redemption-2    4.59           5473
# ...             ...                              ...     ...            ...
# 9981           2008                          de-blob    3.86             42
# 9982           2008           guilty-gear-2-overture    3.00             13
# 9994           2008                      empires-mod    1.64             11
# 9995           2008       silverfall-earth-awakening    3.00             16
# 9996           2008                         mabinogi    3.40             15
#
#       reviews_count  playtime  ...  steam_platform_flags  \
# 0              7499        74  ...                   win
# 2              6143        11  ...            linux, win
# 3              3671        64  ...            linux, win
# 5              3434         9  ...            linux, win
# 7              5605        21  ...                   win
# ...             ...       ...  ...                   ...
# 9981             42         1  ...                   win
# 9982             13         3  ...                   win
# 9994             11         1  ...            linux, win
# 9995             16         1  ...                   win
# 9996             15         2  ...                 music
#
#                                   developers_list  \
# 0                [Rockstar North, Rockstar Games]
# 2                                [Valve Software]
# 3     [Valve Software, Hidden Path Entertainment]
# 5           [Valve Software, Turtle Rock Studios]
# 7                                [Rockstar Games]
# ...                                           ...
# 9981      [THQ Nordic, Blue Tongue Entertainment]
# 9982                           [Arc System Works]
# 9994                                    [Empires]
# 9995                               [Monte Cristo]
# 9996                        [NEXON KOREA, devCAT]
#
#                        publishers_list is_self_published has_win has_mac  \
# 0                     [Rockstar Games]              True    True   False
# 2             [Electronic Arts, Valve]             False    True   False
# 3                              [Valve]             False    True   False
# 5     [Electronic Arts, Valve, Akella]             False    True   False
# 7                     [Rockstar Games]              True    True   False
# ...                                ...               ...     ...     ...
# 9981   [THQ Nordic, THQ, Nordic Games]              True    True   False
# 9982   [Aksys Games, Arc System Works]              True    True   False
# 9994                         [Empires]              True    True   False
# 9995          [Focus Home Interactive]             False    True   False
# 9996            [Nexon, Nexon America]             False   False   False
#
#      has_linux has_ps  has_Nintendo  Price_categorie
# 0        False   True         False               AA
# 2         True   True         False     Small budget
# 3         True   True         False             Free
# 5         True  False         False     Small budget
# 7        False   True         False              AAA
# ...        ...    ...           ...              ...
# 9981     False   True          True     Small budget
# 9982     False  False         False     Small budget
# 9994      True  False         False             Free
# 9995     False  False         False      One guy job
# 9996     False  False         False      One guy job
#
# [2348 rows x 32 columns]

# %%
df_mult = df_mult[df_mult['steam_review_count'] > 100]

# %%
df_mult.groupby('Price_categorie')[['rating', 'steam_review_percent', 'playtime']].count().reset_index()
# Out:
#   Price_categorie  rating  steam_review_percent  playtime
# 0              AA     120                   120       120
# 1             AAA      60                    60        60
# 2            Free     472                   472       472
# 3   Middle budget     255                   255       255
# 4     One guy job     414                   414       414
# 5    Small budget     863                   863       863

# %%
df_gol = df_mult.groupby('Price_categorie')[['rating', 'steam_review_percent', 'playtime']].median().reset_index()
df_gol
# Out:
#   Price_categorie  rating  steam_review_percent  playtime
# 0              AA   3.650                  79.0       6.0
# 1             AAA   3.750                  80.5       8.0
# 2            Free   2.705                  76.0       1.0
# 3   Middle budget   3.540                  82.0       4.0
# 4     One guy job   3.000                  82.5       3.0
# 5    Small budget   3.430                  85.0       3.0

# %%
df_gol = df_gol.sort_values('steam_review_percent', ascending=False)
df_gol1 = df_gol.sort_values('rating', ascending=False)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (16, 5))
ax1.bar(df_gol['Price_categorie'], df_gol['steam_review_percent'])
ax1.tick_params(axis='x', labelrotation=90)
ax2.bar(df_gol1['Price_categorie'], df_gol1['rating'])
ax2.tick_params(axis='x', labelrotation=90)
ax3.bar(df_gol1['Price_categorie'], df_gol1['playtime'])
ax3.tick_params(axis='x', labelrotation=90)
